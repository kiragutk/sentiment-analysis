# %% [markdown]
# ### Twitter Sentiment Analyzer
# https://github.com/llSourcell/twitter_sentiment_challenge

# %%
import tweepy
from textblob import TextBlob
import tkn

# Step 1 - Authenticate

auth = tweepy.OAuthHandler(tkn.consumer_key, tkn.consumer_secret)
auth.set_access_token(tkn.access_key, tkn.access_secret)

api = tweepy.API(auth)

#Step 3 - Retrieve Tweets
public_tweets = api.search('Trump')



#CHALLENGE - Instead of printing out each tweet, save each Tweet to a CSV file
#and label each one as either 'positive' or 'negative', depending on the sentiment 
#You can decide the sentiment polarity threshold yourself


for tweet in public_tweets:
    print(tweet.text)
    
    #Step 4 Perform Sentiment Analysis on Tweets
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
    print("")
# Out:
# RT @InspiringU2: Trump Is Withholding Coronavirus Testing Kits From Governors!
#
# Two governors requested #coronavirus testing kits for their…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @gabedelahaye: If I’m Trump right now I’m thinking about the time they brought the big trucks to the White House and how I got to sit be…
# Sentiment(polarity=0.09523809523809523, subjectivity=0.2119047619047619)
#
# RT @doc_revan: Christopher Steele In Panic Mode, Now Refusing To Cooperate With US Attorney Durham’s Criminal Investigation – The Trump-Rus…
# Sentiment(polarity=-0.4, subjectivity=0.55)
#
# RT @QmagaMike: 💖TRUMP💖z02
# @MRCJUSTRIDEIT◀️🔥
# @MRCRIDE✔️
# @markkirin_
# @KSKitti
# @vmilescmiles
# @AmericanWom3n
# @Dbargen
# @kmc1230
# @1adjutor
# @Schie…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @smalltownandrew: Trump camp fires back after Twitter labels Biden video 'manipulated' sends  Scathing letter to Twitter leadership
#
# So…
# Sentiment(polarity=-0.3, subjectivity=0.5)
#
# RT @neuro7plastic: MUST SEE!😳
# BARRY AUTHORIZED TRUMP COUP VIA EXECUTIVE ORDER! DNI RATCLIFFE’S ROLE IN DRAINING THE SWAMP.
# The whole video…
# Sentiment(polarity=0.2, subjectivity=0.4)
#
# RT @thematthill: UNITED &gt;&gt; The #Joementum continues as @JoeBiden is joined by @KamalaHarris, @gretchenwhitmer, and @CoryBooker in Detroit,…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @HKrassenstein: BREAKING: Trump Is Stalling the release of a US Intel Report that warns that the U.S. is NOT ready for a global pandemic…
# Sentiment(polarity=-0.05, subjectivity=0.25)
#
# RT @1776Stonewall: very misleading headline. She was simply saying that the left is weaponizing it, as they do with everything else, in an…
# Sentiment(polarity=0.06666666666666667, subjectivity=0.21904761904761905)
#
# RT @ThorDeplorable: None of the Democrat candidates would close the border in response to Coronavirus.
#
# Meanwhile President Trump’s plan s…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# @McguireScotty @SIMikeSr Trump promotes Christian values this explains the Democrat's deranged hatred.
#  "...men lov… https://t.co/2whS0t9KMZ
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @joncoopertweets: Trump's mismanagement helped fuel coronavirus crisis 🦠
#
# Current and former administration officials blame Trump for cr…
# Sentiment(polarity=0.0, subjectivity=0.2)
#
# RT @streetnoodle: @dougiepen We frittered it all away because of Trump's ego.
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @neuro7plastic: Trump Tweets Statistics to Put Coronavirus in Perspective
# 🔍👓🔎
# “...people’s lives are being upended, not by the virus, b…
# Sentiment(polarity=0.0, subjectivity=0.0)
#
# RT @MeritLaw: I know Biden supporters and anti Bernie folks just want us all to come together to beat Trump. I get that. I do. But this man…
# Sentiment(polarity=0.0, subjectivity=0.0)
